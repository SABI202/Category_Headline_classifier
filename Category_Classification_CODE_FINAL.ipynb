# %% [markdown]
# ## 🧠 **Project Overview**
#
# **Goal:** Train a machine learning or deep learning model to classify news headlines into categories (e.g., politics, business, tech, sport).
#
# **Example Input:**
#
# > "Tech companies rally in stock market recovery"
# > **Output:**
# > "technology"
#
# ---
#
# ## 🛠️ **Project Workflow Steps**
#
# ### 🔹 1. **Data Collection & Preprocessing**
#
# * Dataset: [News Category Dataset (Kaggle)](https://www.kaggle.com/datasets/rmisra/news-category-dataset)
# * Clean headlines (remove punctuation, lowercasing, etc.)
# * Optional: balance classes (remove overly small ones or downsample)
#
# ---
#
# ### 🔹 2. **Exploratory Data Analysis (EDA)**
#
# * Number of categories
# * Most frequent categories
# * Word frequency per category
# * Headline length stats
#
# ---
#
# ### 🔹 3. **Model Development**
#
# #### 🔸 Classical ML (Baseline)
#
# * Use TF-IDF + Logistic Regression / Naive Bayes
# * Fast training, easy to interpret
#
# #### 🔸 Deep Learning
#
# * Use LSTM, GRU, or even DistilBERT
# * Embedding layer (GloVe or word2vec)
# * Sequence padding & tokenization
#
# ---
#
# ### 🔹 4. **Evaluation**
#
# * Accuracy, Precision, Recall, F1-Score
# * Confusion matrix
# * Per-category performance
#
# ---
#
# ### 🔹 5. **Deployment**
#
# * Streamlit or Gradio web app
# * Input: Headline
# * Output: Predicted category
#
# ---
#
# ### 🔹 6. **Deliverables**
#
# 1. **Word document** (max 10 pages):
#
#    * Abstract, Introduction, Data Description, Method, Results, Conclusion
# 2. **7-min Video Presentation**
#
#    * Code, setup, demo walkthrough, diagrams
# 3. **GitHub Repo**
#
#    * Well-commented code, README, screenshots, video embedded
#
# ---
#
# ## 👬 Work Division (You + Colleague)
#
# | Task               | Description                                                              | Assigned to                                  |
# | ------------------ | ------------------------------------------------------------------------ | -------------------------------------------- |
# | Data Collection    | Download and clean dataset (remove duplicates, punctuation, lowercasing) | **Colleague**                                |
# | Data Analysis      | EDA: visualize word frequencies, length histograms, class counts         | **You**                                      |
# | Baseline Model     | TF-IDF + Logistic Regression, evaluate                                   | **Colleague**                                |
# | DL Model           | LSTM or DistilBERT with tokenizer & training                             | **You**                                      |
# | Evaluation         | Plots, metrics, confusion matrix, analysis                               | **You**                                      |
# | Web App            | Streamlit/Gradio app with input box + output label                       | **Colleague**                                |
# | Report Writing     | Merge both findings into 10-page Word doc                                | **Shared** (start with your sections first)  |
# | Video Presentation | Record code explanation, setup, and demo                                 | **Shared** (split screen time: 3-4 min each) |
# | GitHub Repo        | Push code + README + screenshots + video                                 | **You** (final integration)                  |
#
# ---
#
# ## 🔧 Suggested Tools
#
# * **NLP**: NLTK / spaCy / Hugging Face Transformers
# * **ML**: Scikit-learn
# * **DL**: TensorFlow / PyTorch (for LSTM) or HuggingFace + Transformers
# * **Deployment**: Streamlit or Gradio
# * **Visualization**: matplotlib, seaborn
# * **IDE**: VSCode or Jupyter
#
# ---
#
# ## 🗓️ Timeline (Today to May 20, 2025)
#
# | Week      | Task                                 |
# | --------- | ------------------------------------ |
# | May 17–18 | Data Collection + EDA                |
# | May 19    | Modeling + Evaluation + App          |
# | May 20    | Final Report + Video + GitHub polish |

# %% [markdown]
# <div style="text-align: center;">
#     <img src="image.png" alt="Logo Python" style="width: 90%;"/>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(to left, #0575E6 0%, #021B79 100%);
#     border-radius: 50px;
#     padding: 25px 60px;
#     color: white;
#     font-size: 28px;
#     font-weight: bold;
#     font-family: 'Times New Roman', serif;
#     text-align: center;
#     text-transform: uppercase;
#     letter-spacing: 3px;
#     box-shadow: 0 10px 30px rgba(2, 27, 121, 0.3);
#     border: none;
#     width: fit-content;
#     margin: 60px auto;
#     position: relative;
#     overflow: hidden;
#     cursor: pointer;
#     transition: all 0.4s ease;
#     z-index: 1;
# ">
#     <span style="position: relative; z-index: 2;">DATA EXPLORATION</span>
#     <div style="
#         position: absolute;
#         top: -50%;
#         left: -50%;
#         width: 200%;
#         height: 200%;
#         background: linear-gradient(
#             to right,
#             rgba(255, 255, 255, 0) 20%,
#             rgba(255, 255, 255, 0.2) 50%,
#             rgba(255, 255, 255, 0) 80%
#         );
#         transform: rotate(30deg);
#         transition: all 0.8s ease;
#         z-index: 1;
#         opacity: 0;
#     " class="shine-effect"></div>
# </div>
#
# <script>
#     const button = document.querySelector('div');
#     button.addEventListener('mouseenter', function() {
#         this.querySelector('.shine-effect').style.opacity = '1';
#         this.querySelector('.shine-effect').style.left = '100%';
#         this.style.transform = 'scale(1.05)';
#     });
#     button.addEventListener('mouseleave', function() {
#         this.querySelector('.shine-effect').style.opacity = '0';
#         this.querySelector('.shine-effect').style.left = '-50%';
#         this.style.transform = 'scale(1)';
#     });
# </script>

# %% [markdown]
# ## Load JSON Dataset with Pandas
#
# This code imports a dataset in JSON format using the `pandas` library.

# %%
import pandas as pd

data = pd.read_json("News_Category_Dataset_v3.json",lines= True )

# %% [markdown]
# ## Preview the DataFrame with `head()`
# `data.head()` displays the first 5 rows of the DataFrame data by default.

# %%
data.head()
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# ...

# %% [markdown]
# <br> `data.info()` provides a concise summary of the DataFrame.<br>

# %%
data.describe()
# Out:
#                                 date
# count                         209527
# mean   2015-04-30 00:44:14.344308736
# min              2012-01-28 00:00:00
# 25%              2013-08-10 00:00:00
# 50%              2015-03-16 00:00:00
# 75%              2016-11-01 00:00:00
# max              2022-09-23 00:00:00

# %% [markdown]
# <br> `data.describe()` generates summary statistics of the DataFrame’s numerical columns by default.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209527 entries, 0 to 209526
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   link               209527 non-null  object
#  1   headline           209527 non-null  object
#  2   category           209527 non-null  object
#  3   short_description  209527 non-null  object
#  4   authors            209527 non-null  object
#  5   date               209527 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 9.6+ MB

# %% [markdown]
# <br> creates a new DataFrame called df by selecting only three columns from the original data DataFram

# %%
df= data[['headline', 'category','short_description']]

# %% [markdown]
# ## Visualizing Category Distribution with Seaborn
# import seaborn as sns and import matplotlib.pyplot as plt: Imports the Seaborn and Matplotlib libraries for visualization.<br>
# 	•	sns.countplot(...): Creates a bar plot showing the number of occurrences (count) for each unique value in the category column.<br>
# 	•	data=df: Uses the DataFrame df created earlier.<br>
# 	•	x='category': Plots categories on the x-axis.<br>
# 	•	order=df['category'].value_counts().index: Sorts the categories from most frequent to least.<br>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='category', order=df['category'].value_counts().index)

plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Count of Each Category')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
#     Grouping Similar News Categories
#     • Reduces category fragmentation.
# 	• Helps create cleaner visualizations and better modeling by consolidating similar classes.
# 	• Makes the data more interpretable and easier to analyze.

# %%
# Define your mapping
category_map = {
    'U.S. NEWS': 'NEWS',
    'WORLD NEWS': 'NEWS',
    'THE WORLDPOST': 'NEWS',
    'WORLDPOST': 'NEWS',
    'GOOD NEWS': 'NEWS',
    'WEIRD NEWS': 'NEWS',

    'CULTURE & ARTS': 'ARTS & CULTURE',
    'ARTS & CULTURE': 'ARTS & CULTURE',
    'ARTS': 'ARTS & CULTURE',
    'STYLE': 'ARTS & CULTURE',
    'STYLE & BEAUTY': 'ARTS & CULTURE',

    'WELLNESS': 'LIFESTYLE',
    'HEALTHY LIVING': 'LIFESTYLE',
    'FOOD & DRINK': 'LIFESTYLE',
    'TASTE': 'LIFESTYLE',
    'HOME & LIVING': 'LIFESTYLE',
    'TRAVEL': 'LIFESTYLE',
    'PARENTS': 'LIFESTYLE',
    'PARENTING': 'LIFESTYLE',
    'WEDDINGS': 'LIFESTYLE',
    'DIVORCE': 'LIFESTYLE',
    'WOMEN': 'LIFESTYLE',
    'FIFTY': 'LIFESTYLE',

    'SCIENCE': 'SCIENCE & ENVIRONMENT',
    'GREEN': 'SCIENCE & ENVIRONMENT',
    'ENVIRONMENT': 'SCIENCE & ENVIRONMENT',

    'BLACK VOICES': 'VOICES',
    'QUEER VOICES': 'VOICES',
    'LATINO VOICES': 'VOICES',
    'IMPACT': 'VOICES',

    'COLLEGE': 'EDUCATION',
    'EDUCATION': 'EDUCATION',

    'COMEDY': 'ENTERTAINMENT',
    'ENTERTAINMENT': 'ENTERTAINMENT',
    'MEDIA': 'ENTERTAINMENT',

    'POLITICS': 'POLITICS & BUSINESS',
    'MONEY': 'POLITICS & BUSINESS',
    'BUSINESS': 'POLITICS & BUSINESS',

     'TECH': 'TECHNOLOGY',
     'SPORTS': 'SPORTS',
     'CRIME': 'CRIME',
     'RELIGION': 'RELIGION',
}

# Apply the mapping
df['category_grouped'] = df['category'].map(category_map).fillna(df['category'])
# Out:
# /tmp/ipykernel_4395/3384982432.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['category_grouped'] = df['category'].map(category_map).fillna(df['category'])

# %%
df
# Out:
#                                                  headline   category  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1       American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2       23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3       The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4       Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
# ...                                                   ...        ...
# 209522  RIM CEO Thorsten Heins' 'Significant' Plans Fo...       TECH
# 209523  Maria Sharapova Stunned By Victoria Azarenka I...     SPORTS
# 209524  Giants Over Patriots, Jets Over Colts Among  M...     SPORTS
# 209525  Aldon Smith Arrested: 49ers Linebacker Busted ...     SPORTS
# 209526  Dwight Howard Rips Teammates After Magic Loss ...     SPORTS
#
#                                         short_description category_grouped
# ...

# %% [markdown]
# ## Check for Missing or Empty Values in the DataFrame
# 	• df.isnull(): Returns a DataFrame of the same shape as df with True for missing (NaN) values and False otherwise.
# 	• (df == ""): Returns True where the DataFrame has empty strings.
# 	• `|` (bitwise OR): Combines the two conditions, so it marks True for any cell that is either missing or empty.
# 	• .sum(): Counts the number of True values per column.

# %%
print((df.isnull() | (df == "")).sum())
# Out:
# headline                 6
# category                 0
# short_description    19712
# category_grouped         0
# dtype: int64

# %%
df = df[~df['headline'].isnull() & (df['headline'] != "")]
df = df.reset_index(drop=True)
df
# Out:
#                                                  headline   category  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1       American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2       23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3       The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4       Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
# ...                                                   ...        ...
# 209516  RIM CEO Thorsten Heins' 'Significant' Plans Fo...       TECH
# 209517  Maria Sharapova Stunned By Victoria Azarenka I...     SPORTS
# 209518  Giants Over Patriots, Jets Over Colts Among  M...     SPORTS
# 209519  Aldon Smith Arrested: 49ers Linebacker Busted ...     SPORTS
# 209520  Dwight Howard Rips Teammates After Magic Loss ...     SPORTS
#
#                                         short_description category_grouped  \
# ...

# %%
old_df = df

# %%
print((df.isnull() | (df == "")).sum())
# Out:
# headline                 0
# category                 0
# short_description    19707
# category_grouped         0
# dtype: int64

# %% [markdown]
# ## Visualizing the Distribution of Grouped Categories

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='category_grouped', order=df['category_grouped'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Count of Grouped Categories')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="
#     background: linear-gradient(to left, #0575E6 0%, #021B79 100%);
#     border-radius: 50px;
#     padding: 25px 60px;
#     color: white;
#     font-size: 28px;
#     font-weight: bold;
#     font-family: 'Times New Roman', serif;
#     text-align: center;
#     text-transform: uppercase;
#     letter-spacing: 3px;
#     box-shadow: 0 10px 30px rgba(2, 27, 121, 0.3);
#     border: none;
#     width: fit-content;
#     margin: 60px auto;
#     position: relative;
#     overflow: hidden;
#     cursor: pointer;
#     transition: all 0.4s ease;
#     z-index: 1;
# ">
#     <span style="position: relative; z-index: 2;">LOGISTICAL REGRESSION</span>
#     <div style="
#         position: absolute;
#         top: -50%;
#         left: -50%;
#         width: 200%;
#         height: 200%;
#         background: linear-gradient(
#             to right,
#             rgba(255, 255, 255, 0) 20%,
#             rgba(255, 255, 255, 0.2) 50%,
#             rgba(255, 255, 255, 0) 80%
#         );
#         transform: rotate(30deg);
#         transition: all 0.8s ease;
#         z-index: 1;
#         opacity: 0;
#     " class="shine-effect"></div>
# </div>
#
# <script>
#     const button = document.querySelector('div');
#     button.addEventListener('mouseenter', function() {
#         this.querySelector('.shine-effect').style.opacity = '1';
#         this.querySelector('.shine-effect').style.left = '100%';
#         this.style.transform = 'scale(1.05)';
#     });
#     button.addEventListener('mouseleave', function() {
#         this.querySelector('.shine-effect').style.opacity = '0';
#         this.querySelector('.shine-effect').style.left = '-50%';
#         this.style.transform = 'scale(1)';
#     });
# </script>

# %% [markdown]
# 	•pandas as pd:
#         For data manipulation and analysis, especially to load and handle tabular data (like CSV files).
#
# 	•numpy as np:
#         Provides numerical operations, arrays, and matrix computations needed during data processing.
#
#     •train_test_split (from sklearn.model_selection):
#         To split your dataset into training and testing sets for model evaluation.
#
#     •LogisticRegression (from sklearn.linear_model):
#         A simple and effective linear model used here for classification tasks.
#
#     •classification_report (from sklearn.metrics):
#         To generate a detailed report showing precision, recall, f1-score, and accuracy after predictions.
#
#     •LabelEncoder (from sklearn.preprocessing):
#         Encodes categorical labels into numerical values to train the model.
#
#     •Pipeline (from sklearn.pipeline):
#         Allows chaining preprocessing steps (like vectorization) and the model into one streamlined workflow.
#
#     •TfidfVectorizer (from sklearn.feature_extraction.text):
#         Converts raw text into TF-IDF features, a numerical representation of text useful for machine learning models.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# This snippet prepares your text data and labels for training a supervised classification model by:<br>
# 	•	Creating the text input feature.<br>
# 	•	Encoding the target categories as numbers.<br>
# 	•	Splitting the dataset properly into training and testing subsets.<br>

# %%
X = (df['headline'] + " " + df['short_description']).fillna("")

# Encode categorical labels
le = LabelEncoder()
y = le.fit_transform(df['category_grouped'])

# Split the data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %% [markdown]
# This pipeline neatly packages text vectorization and model training into a single object. It’s designed to:<br>
# 	•	Extract meaningful `TF-IDF` features from your text data.<br>
# 	•	Train a logistic regression model capable of handling multiple categories.<br>
#
# You can now train this pipeline directly with your training data and then predict or evaluate it on new samples.

# %%
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(max_features=10000, ngram_range=(1, 2))),
    ('clf', LogisticRegression(
        multi_class='multinomial',  # softmax regression
        solver='lbfgs',
        max_iter=1000,
        random_state=42
    ))
])

# %% [markdown]
# <br>This line trains the machine learning pipeline using the training data. It fits the TfidfVectorizer on the input text (X_train) and transforms it into feature vectors. Then, it trains the LogisticRegression model on the corresponding labels (y_train). The entire process is handled in one step through the pipeline.

# %%
pipeline.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_features=10000, ngram_range=(1, 2))),
#                 ('clf',
#                  LogisticRegression(max_iter=1000, multi_class='multinomial',
#                                     random_state=42))])

# %% [markdown]
# <br>The trained pipeline to predict labels for the test data (X_test). The predicted labels are stored in y_pred. Then, it prints a classification report comparing the true labels (y_test) to the predictions. The report includes metrics like precision, recall, and F1-score for each category.

# %%
y_pred = pipeline.predict(X_test)
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
#                        precision    recall  f1-score   support
#
#        ARTS & CULTURE       0.80      0.62      0.70      3198
#                 CRIME       0.56      0.42      0.48       712
#             EDUCATION       0.54      0.24      0.33       432
#         ENTERTAINMENT       0.66      0.67      0.66      5141
#             LIFESTYLE       0.74      0.90      0.81     14419
#                  NEWS       0.62      0.51      0.56      3019
#   POLITICS & BUSINESS       0.72      0.79      0.76      8670
#              RELIGION       0.67      0.30      0.42       515
# SCIENCE & ENVIRONMENT       0.61      0.37      0.46      1254
#                SPORTS       0.74      0.52      0.61      1015
#            TECHNOLOGY       0.62      0.27      0.38       421
#                VOICES       0.66      0.43      0.53      3109
#
#              accuracy                           0.71     41905
#             macro avg       0.66      0.50      0.56     41905
# ...

# %% [markdown]
# <br>Imports the confusion_matrix function from scikit-learn to evaluate the model’s predictions. It computes the confusion matrix by comparing the true labels (y_test) with the predicted labels (y_pred). The confusion matrix shows the counts of correct and incorrect predictions for each class. Finally, it prints the confusion matrix to help assess model performance.

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[ 1984     0     4   274   737    31   102     3    14     8     1    40]
#  [    3   297     1    28    93   125   120     1     3     5     0    36]
#  [    1     8   105    12   139     8   130     3     2     0     1    23]
#  [  116    19     4  3419   777   100   485     8    21    43     7   142]
#  [  208     8    20   351 12985   132   455    11    64    48    16   121]
#  [   37    71     9   181   535  1527   461    24    73    30     4    67]
#  [   37    55    38   314   821   254  6846    14    82    17    33   159]
#  [    6     4     2    27   144    47    75   157     7     4     0    42]
#  [   15     1     0    51   409   112   165     2   466     4     2    27]
#  [   14    15     2   136   161    37    85     0     8   531     1    25]
#  [    7     0     1    43   126    13   105     1     6     0   115     4]
#  [   67    52     9   340   706    91   420    12    23    31     6  1352]]

# %% [markdown]
# <br>
# Calculates True Positives (TP), False Positives (FP), False Negatives (FN), and True Negatives (TN) from the confusion matrix. It sums these values across all classes to get total counts. Then, it prints the overall totals, including the total number of samples. This helps in understanding the detailed performance of the classification model.

# %%
TP = np.diag(cm)
FP = np.sum(cm, axis=0) - TP
FN = np.sum(cm, axis=1) - TP
TN = np.sum(cm) - (TP + FP + FN)

# Total sums
total_TP = TP.sum()
total_FP = FP.sum()
total_FN = FN.sum()
total_TN = TN.sum()

print("\n=== Totals ===")
print(f"Total samples: {cm.sum()}")
print(f"True Positives (TP): {total_TP}")
print(f"False Positives (FP): {total_FP}")
print(f"False Negatives (FN): {total_FN}")
print(f"True Negatives (TN): {total_TN}")
# Out:
# === Totals ===
# Total samples: 41905
# True Positives (TP): 29784
# False Positives (FP): 12121
# False Negatives (FN): 12121
# True Negatives (TN): 448834

# %% [markdown]
# <br>This code imports the pickle module to handle object serialization. It opens a file named `multiclass_logistic_regression.pkl` in write-binary mode. <br>The trained machine learning pipeline is then saved (serialized) into this file. This allows the model to be stored and loaded later without retraining.

# %%
import pickle
with open('multiclass_logistic_regression.pkl', 'wb') as f:
    pickle.dump(pipeline, f)

# %% [markdown]
# <div style="
#     background: linear-gradient(to left, #0575E6 0%, #021B79 100%);
#     border-radius: 50px;
#     padding: 25px 60px;
#     color: white;
#     font-size: 28px;
#     font-weight: bold;
#     font-family: 'Times New Roman', serif;
#     text-align: center;
#     text-transform: uppercase;
#     letter-spacing: 3px;
#     box-shadow: 0 10px 30px rgba(2, 27, 121, 0.3);
#     border: none;
#     width: fit-content;
#     margin: 60px auto;
#     position: relative;
#     overflow: hidden;
#     cursor: pointer;
#     transition: all 0.4s ease;
#     z-index: 1;
# ">
#     <span style="position: relative; z-index: 2;">DISTILBERT TRANSFORMER</span>
#     <div style="
#         position: absolute;
#         top: -50%;
#         left: -50%;
#         width: 200%;
#         height: 200%;
#         background: linear-gradient(
#             to right,
#             rgba(255, 255, 255, 0) 20%,
#             rgba(255, 255, 255, 0.2) 50%,
#             rgba(255, 255, 255, 0) 80%
#         );
#         transform: rotate(30deg);
#         transition: all 0.8s ease;
#         z-index: 1;
#         opacity: 0;
#     " class="shine-effect"></div>
# </div>
#
# <script>
#     const button = document.querySelector('div');
#     button.addEventListener('mouseenter', function() {
#         this.querySelector('.shine-effect').style.opacity = '1';
#         this.querySelector('.shine-effect').style.left = '100%';
#         this.style.transform = 'scale(1.05)';
#     });
#     button.addEventListener('mouseleave', function() {
#         this.querySelector('.shine-effect').style.opacity = '0';
#         this.querySelector('.shine-effect').style.left = '-50%';
#         this.style.transform = 'scale(1)';
#     });
# </script>

# %% [markdown]
# 	1.Prétraitement des données :
#     		La colonne text est créée en concaténant la colonne headline et short_description (en remplaçant les valeurs manquantes par des chaînes vides).
#     		Les catégories textuelles category_grouped sont encodées en valeurs numériques à l’aide de LabelEncoder.
#     		Le nombre total de classes (num_classes) est calculé.
#
# 	2.Division du jeu de données :Le DataFrame est divisé en ensembles d’entraînement et de test (80% / 20%) en stratifiant selon la distribution des classes pour équilibrer les labels.
#
# 	3.Tokenisation :
#     		Le tokenizer DistilBERT est chargé (distilbert-base-uncased).
#     		Le texte est tokenisé en séquences de tokens avec une longueur maximale de 128, avec padding et troncature automatique.
#     		Les colonnes inutiles sont supprimées, et le format des données est fixé pour PyTorch.
#
#     4.Chargement du modèle DistilBERT :Un modèle pré-entraîné DistilBERT pour la classification est chargé, avec un nombre de sorties adapté au nombre de classes.
#
#     5.Configuration des arguments d’entraînement :
#     		Définit où sauvegarder les résultats.
#     		Evaluation et sauvegarde du modèle à chaque époque.
#     		Limitation du nombre de modèles sauvegardés.
#     		Chargement du meilleur modèle à la fin (meilleur selon la métrique accuracy).
#     		Paramètres d’entraînement : nombre d’époques, taille des batchs, weight decay, logging, label smoothing, utilisation du mixed precision (fp16) pour accélérer sur GPU.
#
#     6.Définition des métriques d’évaluation :Calcul des métriques classiques pour la classification : précision, rappel, F1-score (moyenne pondérée), et exactitude (accuracy).
#
#     7.Création du Trainer :Le Trainer de Hugging Face est instancié avec le modèle, les datasets, les arguments d’entraînement et la fonction de métriques.
#
#     8.Entraînement :Lancement du processus d’entraînement.
#
#     9.Sauvegarde finale :Le meilleur modèle et le tokenizer sont sauvegardés dans le dossier ./results/best_model.

# %%
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset, DatasetDict
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import pandas as pd
import torch

# %%
df['text'] = df['headline'].fillna('') + ' ' + df['short_description'].fillna('')
label_encoder = LabelEncoder()
df['label'] = label_encoder.fit_transform(df['category_grouped'])
num_classes = len(label_encoder.classes_)

# %%
train_df, test_df = train_test_split(df[['text', 'label']], test_size=0.2, stratify=df['label'], random_state=42)
dataset = DatasetDict({
    'train': Dataset.from_pandas(train_df.reset_index(drop=True)),
    'test': Dataset.from_pandas(test_df.reset_index(drop=True))
})

# %%
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
def tokenize_fn(example):
    return tokenizer(example['text'], padding='max_length', truncation=True, max_length=128)

dataset = dataset.map(tokenize_fn, batched=True)
dataset = dataset.remove_columns(['text'])
dataset.set_format('torch')

# %%
model = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=num_classes)

# %%
training_args = TrainingArguments(
    output_dir='./results',
    eval_strategy='epoch',
    save_strategy='epoch',
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model='accuracy',
    greater_is_better=True,
    num_train_epochs=3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.1,
    logging_dir='./logs',
    logging_steps=50,
    label_smoothing_factor=0.1,
    fp16=True
)

# %%
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset['train'],
    eval_dataset=dataset['test'],
    compute_metrics=compute_metrics)

# %%
trainer.train()

#Save final model
trainer.save_model("./results/best_model")
tokenizer.save_pretrained("./results/best_model")

# %%
import joblib

# Reuse the same label encoder you trained with
joblib.dump(label_encoder, './results/best_model/label_encoder.pkl')

# %%
from transformers import DistilBertForSequenceClassification, DistilBertTokenizer

# Load model and tokenizer
model = DistilBertForSequenceClassification.from_pretrained("./results/best_model")
tokenizer = DistilBertTokenizer.from_pretrained("./results/best_model")

# Example: Inference on new text
text = "Breaking news: "
inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=128)

# Run prediction
model.eval()
with torch.no_grad():
    outputs = model(**inputs)
    probs = torch.nn.functional.softmax(outputs.logits, dim=1)
    predicted_label = torch.argmax(probs, dim=1).item()

label_encoder = joblib.load('./results/best_model/label_encoder.pkl')


print("Predicted label:", label_encoder.inverse_transform([predicted_label]))

# %%
# !zip -r results.zip results

# %% [markdown]
# <div style="
#     background: linear-gradient(to left, #0575E6 0%, #021B79 100%);
#     border-radius: 50px;
#     padding: 25px 60px;
#     color: white;
#     font-size: 28px;
#     font-weight: bold;
#     font-family: 'Times New Roman', serif;
#     text-align: center;
#     text-transform: uppercase;
#     letter-spacing: 3px;
#     box-shadow: 0 10px 30px rgba(2, 27, 121, 0.3);
#     border: none;
#     width: fit-content;
#     margin: 60px auto;
#     position: relative;
#     overflow: hidden;
#     cursor: pointer;
#     transition: all 0.4s ease;
#     z-index: 1;
# ">
#     <span style="position: relative; z-index: 2;">JOBLIB</span>
#     <div style="
#         position: absolute;
#         top: -50%;
#         left: -50%;
#         width: 200%;
#         height: 200%;
#         background: linear-gradient(
#             to right,
#             rgba(255, 255, 255, 0) 20%,
#             rgba(255, 255, 255, 0.2) 50%,
#             rgba(255, 255, 255, 0) 80%
#         );
#         transform: rotate(30deg);
#         transition: all 0.8s ease;
#         z-index: 1;
#         opacity: 0;
#     " class="shine-effect"></div>
# </div>
#
# <script>
#     const button = document.querySelector('div');
#     button.addEventListener('mouseenter', function() {
#         this.querySelector('.shine-effect').style.opacity = '1';
#         this.querySelector('.shine-effect').style.left = '100%';
#         this.style.transform = 'scale(1.05)';
#     });
#     button.addEventListener('mouseleave', function() {
#         this.querySelector('.shine-effect').style.opacity = '0';
#         this.querySelector('.shine-effect').style.left = '-50%';
#         this.style.transform = 'scale(1)';
#     });
# </script>

# %% [markdown]
# The code uses joblib.dump to serialize the trained LabelEncoder, allowing you to load it later with joblib.load for consistent label mapping between training and prediction phases.

# %%
import joblib

# Reuse the same label encoder you trained with
joblib.dump(label_encoder, './results/best_model/label_encoder.pkl')

# %% [markdown]
# 1.	Load the model and tokenizer:
# Load the fine-tuned DistilBERT model and its corresponding tokenizer from the saved directory (./results/best_model).
# 2.	Prepare input text:
# A sample text "Breaking news: " is tokenized, converted to input tensors with padding and truncation to a max length of 128 tokens.
# 3.	Run the model in evaluation mode:
# Disable gradient calculations (torch.no_grad()) for efficiency during inference.
# Pass the tokenized inputs to the model to get raw logits.
# 4.	Convert logits to probabilities:
# Apply softmax to logits to obtain class probabilities.
# 5.	Predict the label:
# Take the class with the highest probability as the predicted label index.
# 6.	Load the label encoder:
# The saved LabelEncoder is loaded from disk to convert the predicted numeric label back to its original text category.
# 7.	Print the predicted label:
# Outputs the readable category name corresponding to the predicted label.

# %%
from transformers import DistilBertForSequenceClassification, DistilBertTokenizer

# Load model and tokenizer
model = DistilBertForSequenceClassification.from_pretrained("./results/best_model")
tokenizer = DistilBertTokenizer.from_pretrained("./results/best_model")

# Example: Inference on new text
text = "Breaking news: "
inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=128)

# Run prediction
model.eval()
with torch.no_grad():
    outputs = model(**inputs)
    probs = torch.nn.functional.softmax(outputs.logits, dim=1)
    predicted_label = torch.argmax(probs, dim=1).item()
# Load it when needed
label_encoder = joblib.load('./results/best_model/label_encoder.pkl')


print("Predicted label:", label_encoder.inverse_transform([predicted_label]))
# Out:
# Predicted label: ['SCIENCE & ENVIRONMENT']
